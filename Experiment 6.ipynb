# %%
import sqlite3 

conn=sqlite3.connect('example.db') 

cursor = conn.cursor() 

table='''CREATE TABLE Student1( 

        first_name CHAR(20), 

        last_name CHAR(20), 

        roll_no INT, 

        sex CHAR(20) 

        )''' 

conn.execute(table) 

print('Table created successfully') 

conn.commit() 

conn.close()
# Out:
# Table created successfully

# %%
import sqlite3 

conn=sqlite3.connect('example.db') 

cursor = conn.cursor() 

table='''CREATE TABLE Student1( 

        first_name CHAR(20), 

        last_name CHAR(20), 

        roll_no INT, 

        sex CHAR(20) 

        )''' 

conn.execute('''INSERT INTO Student1

               (first_name,last_name,roll_no,sex) 

               VALUES('Ram','Patil',34,'M'), 

               ('Riya','Sharma',45,'F'), 

               ('Diya','Mirza',23,'F')''') 

table=''' UPDATE Student SET roll_no=roll_no-1 WHERE sex='M' ''' 

cursor.execute(table) 

cursor.execute('''SELECT * FROM Student1''') 

 

print(cursor.fetchall()) 

conn.commit() 

conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-5fa4c1cc84f7> in <module>
#      29 table=''' UPDATE Student SET roll_no=roll_no-1 WHERE sex='M' '''
#      30
# ---> 31 cursor.execute(table)
#      32
#      33 cursor.execute('''SELECT * FROM Student1''')
#
# OperationalError: no such table: Student
