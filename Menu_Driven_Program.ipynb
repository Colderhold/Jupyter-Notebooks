# %%
def create_list():
  n=int(input(print('Enter the number of elements in list ')))
  for i in range(0,n):
    x=int(input(print('Enter the element ')))
    if x%2==0:
      even.append(x)
    else:
      odd.append(x)
  print(even)
  print(odd)

def merge_and_sort():
  v=even+odd
  v.sort()
  return v

def update_and_delete(v):
  x=int(input(print('Enter the number to be replaced at first position ')))
  v.pop(0)
  v.insert(0,x)
  print(v)
  p=len(v)
  if p%2==0:
    print(v)
  else:
    v.pop(int((p-1)/2))
    print(v)
  print('Maximum is ')
  print(max(v))
  print('Minimum is ')
  print(min(v))

def add_names():
  name_list = ['Dhruv','Najeeb','Serin','Tarun','Python']
  o=v+name_list
  print(o)
  p=len(o)
  for i in range(0,p):
    if 'Python' in o:
      return 1
    else:
      return 0

even=[]
odd=[]
n=0
while n!= 5:
  n=int(input(print('Enter your choice ')))
  print('Enter 5 to exit ')
  if n==1:
   create_list()
  elif n==2:
   v=merge_and_sort()
   print(v)
  elif n==3:
   update_and_delete(v)
  elif n==4:
   u=add_names()
   if u==1:
    print('Python is present')
   else:
    print('Python not present')
# Out:
# Enter your choice
# None1
# Enter 5 to exit
# Enter the number of elements in list
# None5
# Enter the element
# None4
# Enter the element
# None3
# Enter the element
# None2
# Enter the element
# None5
# Enter the element
# None1
# [4, 2]
# [3, 5, 1]
# Enter your choice
# None2
# Enter 5 to exit
# [1, 2, 3, 4, 5]
# Enter your choice
# None3
# Enter 5 to exit
# Enter the number to be replaced at first position
# None6
# [6, 2, 3, 4, 5]
# [6, 2, 4, 5]
# Maximum is
# 6
# Minimum is
# 2
# Enter your choice
# None4
# Enter 5 to exit
# [6, 2, 4, 5, 'Dhruv', 'Najeeb', 'Serin', 'Tarun', 'Python']
# Python is present
# Enter your choice
# None5
# Enter 5 to exit
